# %% [markdown]
# # Plots

# %%
import pandas as pd 
import numpy as np 
import re
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')
import seaborn as sns
sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

# %%
import os

# %%
mob_male = pd.read_csv('../data/sim_male_m1.csv')

# %%
mob_female = pd.read_csv('../data/sim_female_f1.csv')

# %%
mob_male.loc[mob_male['q']==3,:].head()
# Out:
#       q        fd
# 4000  3 -0.303916
# 4001  3 -0.299425
# 4002  3 -0.322147
# 4003  3 -0.318088
# 4004  3 -0.266771

# %%
mob_female.loc[mob_female['q']==1,:].head()
# Out:
#    q        fd
# 0  1 -0.361945
# 1  1 -0.331027
# 2  1 -0.373891
# 3  1 -0.253584
# 4  1 -0.353284

# %%
sns.kdeplot(mob_male.loc[mob_male.q==1, 'fd'], label='Q1', shade=True, alpha=0.4)
sns.kdeplot(mob_male.loc[mob_male.q==2, 'fd'], label='Q2', shade=True, alpha=0.2)
sns.kdeplot(mob_male.loc[mob_male.q==3, 'fd'], label='Q3', shade=True, alpha=0.2)
sns.kdeplot(mob_male.loc[mob_male.q==4, 'fd'], label='Q4', shade=True, alpha=0.2)
# sns.kdeplot(data.split_frac[data.gender=='W'], label='women', shade=True)
plt.xlabel('Life expectancy (40) first difference \n One standard deviation increase in rank-rank slope');
plt.ylabel('Density');
plt.ylim([0, 12])
plt.legend(ncol=4, loc="upper center");
plt.axvline(x=0.0, color='grey', linewidth=1, linestyle='--')
plt.savefig('plots/first_difference_male_mob_m1.pdf');

# %%
sns.kdeplot(mob_female.loc[mob_female.q==1, 'fd'], label='Q1', shade=True, alpha=0.2)
sns.kdeplot(mob_female.loc[mob_female.q==2, 'fd'], label='Q2', shade=True, alpha=0.2)
sns.kdeplot(mob_female.loc[mob_female.q==3, 'fd'], label='Q3', shade=True, alpha=0.2)
sns.kdeplot(mob_female.loc[mob_female.q==4, 'fd'], label='Q4', shade=True, alpha=0.2)
plt.xlabel('Life expectancy (40) first difference \n One standard deviation increase in rank-rank slope');
plt.ylabel('Density');
plt.ylim([0, 12])
plt.legend(ncol=4, loc="upper center");
plt.axvline(x=0.0, color='grey', linewidth=1, linestyle='--')
plt.savefig('plots/first_difference_female_mob_f1.pdf')

# %% [markdown]
# # Inequality

# %%
# gini_male = pd.read_csv('../data/sim_gini_male_m1.csv')
# gini_female = pd.read_csv('../data/sim_gini_female_m1.csv')

# %%
#gini_male.loc[gini_male['q']==1,:].head()

# %%
#gini_male.loc[gini_male['q']==2,:].head()

# %%
# sns.kdeplot(gini_male.loc[gini_male.q==1, 'diff'], label='Q1', shade=True, alpha=0.4)
# sns.kdeplot(gini_male.loc[gini_male.q==2, 'diff'], label='Q2', shade=True, alpha=0.2)
# sns.kdeplot(gini_male.loc[gini_male.q==3, 'diff'], label='Q3', shade=True, alpha=0.2)
# sns.kdeplot(gini_male.loc[gini_male.q==4, 'diff'], label='Q4', shade=True, alpha=0.4)
# plt.xlabel('Life expectancy first difference \n One standard deviation increase in inequality');
# plt.ylabel('Density');
# plt.ylim([0, 12])
# plt.legend(ncol=4, loc="upper center");
# plt.axvline(x=0.0, color='grey', linewidth=1, linestyle='--')
# plt.savefig('plots/first_difference_male_gini_m1.pdf')

# %%
# sns.kdeplot(gini_female.loc[gini_female.q==1, 'diff'], label='Q1', shade=True, alpha=0.4)
# sns.kdeplot(gini_female.loc[gini_female.q==2, 'diff'], label='Q2', shade=True, alpha=0.2)
# sns.kdeplot(gini_female.loc[gini_female.q==3, 'diff'], label='Q3', shade=True, alpha=0.2)
# sns.kdeplot(gini_female.loc[gini_female.q==4, 'diff'], label='Q4', shade=True, alpha=0.4)
# plt.xlabel('Life expectancy first difference \n One standard deviation increase in inequality');
# plt.ylabel('Density');
# plt.ylim([0, 12])
# plt.legend(ncol=4, loc="upper center");
# plt.axvline(x=0.0, color='grey', linewidth=1, linestyle='--')
# plt.savefig('plots/first_difference_female_gini_m1.pdf')

# %% [markdown]
# # Adjusting for contextual factors

# %%
mob_male = pd.read_csv('../data/sim_male_m2.csv')
mob_female = pd.read_csv('../data/sim_female_f2.csv')

# %% [markdown]
# ### Mobility

# %%
sns.kdeplot(mob_male.loc[mob_male.q==1, 'fd'], label='Q1', shade=True, alpha=0.4)
sns.kdeplot(mob_male.loc[mob_male.q==2, 'fd'], label='Q2', shade=True, alpha=0.2)
sns.kdeplot(mob_male.loc[mob_male.q==3, 'fd'], label='Q3', shade=True, alpha=0.2)
sns.kdeplot(mob_male.loc[mob_male.q==4, 'fd'], label='Q4', shade=True, alpha=0.2)
# sns.kdeplot(data.split_frac[data.gender=='W'], label='women', shade=True)
plt.xlabel('Life expectancy (40) first difference \n One standard deviation increase in rank-rank slope');
plt.ylabel('Density');
plt.ylim([0, 12])
plt.legend(ncol=4, loc="upper center");
plt.axvline(x=0.0, color='grey', linewidth=1, linestyle='--')
plt.savefig('plots/first_difference_male_mob_m2.pdf');

# %%
sns.kdeplot(mob_female.loc[mob_female.q==1, 'fd'], label='Q1', shade=True, alpha=0.2)
sns.kdeplot(mob_female.loc[mob_female.q==2, 'fd'], label='Q2', shade=True, alpha=0.2)
sns.kdeplot(mob_female.loc[mob_female.q==3, 'fd'], label='Q3', shade=True, alpha=0.2)
sns.kdeplot(mob_female.loc[mob_female.q==4, 'fd'], label='Q4', shade=True, alpha=0.2)
plt.xlabel('Life expectancy (40) first difference \n One standard deviation increase in rank-rank slope');
plt.ylabel('Density');
plt.ylim([0, 12])
plt.legend(ncol=4, loc="upper center");
plt.axvline(x=0.0, color='grey', linewidth=1, linestyle='--')
plt.savefig('plots/first_difference_female_mob_f2.pdf')

# %% [markdown]
# ### Inequality

# %%
# gini_male = pd.read_csv('../data/sim_gini_male_m2.csv')
# gini_female = pd.read_csv('../data/sim_gini_female_m2.csv')

# %%
# sns.kdeplot(gini_male.loc[gini_male.q==1, 'diff'], label='Q1', shade=True, alpha=0.4)
# sns.kdeplot(gini_male.loc[gini_male.q==2, 'diff'], label='Q2', shade=True, alpha=0.2)
# sns.kdeplot(gini_male.loc[gini_male.q==3, 'diff'], label='Q3', shade=True, alpha=0.2)
# sns.kdeplot(gini_male.loc[gini_male.q==4, 'diff'], label='Q4', shade=True, alpha=0.4)
# plt.xlabel('Life expectancy first difference \n One standard deviation increase in inequality');
# plt.ylabel('Density');
# plt.ylim([0, 12])
# plt.legend(ncol=4, loc="upper center");
# plt.axvline(x=0.0, color='grey', linewidth=1, linestyle='--')
# plt.savefig('plots/first_difference_male_gini_m2.pdf')

# %%
# sns.kdeplot(gini_female.loc[gini_female.q==1, 'diff'], label='Q1', shade=True, alpha=0.4)
# sns.kdeplot(gini_female.loc[gini_female.q==2, 'diff'], label='Q2', shade=True, alpha=0.2)
# sns.kdeplot(gini_female.loc[gini_female.q==3, 'diff'], label='Q3', shade=True, alpha=0.2)
# sns.kdeplot(gini_female.loc[gini_female.q==4, 'diff'], label='Q4', shade=True, alpha=0.4)
# plt.xlabel('Life expectancy first difference \n One standard deviation increase in inequality');
# plt.ylabel('Density');
# plt.ylim([0, 12])
# plt.legend(ncol=4, loc="upper center");
# plt.axvline(x=0.0, color='grey', linewidth=1, linestyle='--')
# plt.savefig('plots/first_difference_female_gini_m2.pdf')

# %% [markdown]
# # Mediators

# %%
# mob_male = pd.read_csv('../data/sim_mob_male_m3.csv')
# mob_female = pd.read_csv('../data/sim_mob_female_m3.csv')

# %%
# sns.kdeplot(mob_male.loc[mob_male.q==1, 'diff'], label='Q1', shade=True, alpha=0.4)
# sns.kdeplot(mob_male.loc[mob_male.q==2, 'diff'], label='Q2', shade=True, alpha=0.2)
# sns.kdeplot(mob_male.loc[mob_male.q==3, 'diff'], label='Q3', shade=True, alpha=0.2)
# sns.kdeplot(mob_male.loc[mob_male.q==4, 'diff'], label='Q4', shade=True, alpha=0.2)
# # sns.kdeplot(data.split_frac[data.gender=='W'], label='women', shade=True)
# plt.xlabel('Life expectancy first difference \n One standard deviation increase in rank-rank slope');
# plt.ylabel('Density');
# plt.ylim([0, 12])
# plt.legend(ncol=4, loc="upper center");
# plt.axvline(x=0.0, color='grey', linewidth=1, linestyle='--')
# plt.savefig('plots/first_difference_male_mob_m3.pdf')

# %%
# sns.kdeplot(mob_female.loc[mob_female.q==1, 'diff'], label='Q1', shade=True, alpha=0.2)
# sns.kdeplot(mob_female.loc[mob_female.q==2, 'diff'], label='Q2', shade=True, alpha=0.2)
# sns.kdeplot(mob_female.loc[mob_female.q==3, 'diff'], label='Q3', shade=True, alpha=0.2)
# sns.kdeplot(mob_female.loc[mob_female.q==4, 'diff'], label='Q4', shade=True, alpha=0.2)
# plt.xlabel('Life expectancy first difference \n One standard deviation increase in rank-rank slope');
# plt.ylabel('Density');
# plt.ylim([0, 12])
# plt.legend(ncol=4, loc="upper center");
# plt.axvline(x=0.0, color='grey', linewidth=1, linestyle='--')
# plt.savefig('plots/first_difference_female_mob_m3.pdf')
